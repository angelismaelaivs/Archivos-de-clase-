# %% [markdown]
# <a href="https://colab.research.google.com/github/angelismaelaivs/Archivos-de-clase-/blob/main/Clase1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("hola mundo")
# Out:
# hola mundo

# %%
print(1+2)
# Out:
# 3

# %%
print("1"+"2")
# Out:
# 12

# %%
a=1
b=2
c=a+b
print(c)
# Out:
# 3

# %%
print("Vamos a calcular la altura de un rectangulo")
altura=input("Dame la altura:")
base=input("Dame la base:")
area=int(altura)*int(base)
mensaje="El area del rectangulo es:"
resultado=mensaje+" "+str(area)
print(resultado)
# Out:
# Vamos a calcular la altura de un rectangulo
# Dame la altura:3
# Dame la base:5
# El area del rectangulo es: 15
